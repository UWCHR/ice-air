# %%
import pandas as pd
import numpy as np
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import cartopy.io.shapereader as shpreader
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.colors as colors
from mpl_toolkits.axes_grid1 import make_axes_locatable
from matplotlib.ticker import LogFormatter
import networkx as nx

# %%
# County table adapted from: https://en.wikipedia.org/wiki/User:Michael_J/County_table
county_table = pd.read_csv('../input/counties.csv.gz', sep='|', quotechar='"', compression='gzip')

# %%
# counties = reader.records()
# county = next(counties)

# %%
county_table.head()
# Out:
#    Sort State  FIPS   County County Seat(s)  Population\n(2010)  \
# 0     1    AL  1001  Autauga     Prattville               54571
# 1     2    AL  1003  Baldwin    Bay Minette              182265
# 2     3    AL  1005  Barbour        Clayton               27457
# 3     4    AL  1007     Bibb    Centreville               22915
# 4     5    AL  1009   Blount        Oneonta               57322
#
#    Land Area\nkm sq  Land Area\nmi sq Water Area\nkm sq Water Area\nmi sq  \
# 0          1539.582           594.436            25.776             9.952
# 1          4117.522          1589.784           1133.19           437.527
# 2          2291.819           884.876            50.865            19.639
# 3          1612.481           622.582             9.289             3.587
# 4          1669.962           644.776            15.157             5.852
#
#    Total Area\nkm sq  Total Area\nmi sq   Latitude  Longitude
# 0           1565.358            604.388  32.536382 -86.644490
# ...

# %%
nw_states = ['WA', 'OR', 'ID', 'MT']

# %%
nw_counties = county_table[county_table['State'].isin(nw_states)]

# %%
nw_counties.head()
# Out:
#      Sort State   FIPS     County County Seat(s)  Population\n(2010)  \
# 551   552    ID  16001        Ada          Boise              392365
# 552   553    ID  16003      Adams        Council                3976
# 553   554    ID  16005    Bannock      Pocatello               82839
# 554   555    ID  16007  Bear Lake          Paris                5986
# 555   556    ID  16009    Benewah     St. Maries                9285
#
#      Land Area\nkm sq  Land Area\nmi sq Water Area\nkm sq Water Area\nmi sq  \
# 551          2726.158          1052.576            20.425             7.886
# 552          3530.299          1363.056            17.392             6.715
# 553          2880.035          1111.988            91.801            35.444
# 554          2524.681           974.785           193.274            74.623
# 555          2011.429           776.617            18.988             7.331
#
#      Total Area\nkm sq  Total Area\nmi sq   Latitude   Longitude
# ...

# %%
fips = nw_counties[['FIPS', 'County', 'State']]

# %%
fips[fips['County'] == 'Yakima']['FIPS']
# Out:
# 2992    53077
# Name: FIPS, dtype: int64

# %%
yak_detainers = pd.read_csv('../input/YakimaDetainers.csv')

# %%
yak_detainers.head()
# Out:
#   Booking ID  Date of Booking Date of Release Length of Detention  \
# 0         NaN       10/1/2016       10/5/2016                   4
# 1         NaN       10/3/2016         10/5/16                   2
# 2         NaN       10/3/2016         10/5/16                   2
# 3         NaN       10/4/2016         10/6/16                   2
# 4         NaN       10/4/2016            10/5                   1
#
#               Charge  County/Family Connections  Country of Origin  \
# 0                DUI                         NaN            Mexico
# 1                NaN                         NaN            Mexico
# 2  Child Molestation                         NaN            Mexico
# 3        Immigration                         NaN            Mexico
# 4                NaN                         NaN            Mexico
#
#   Coming from Jail?  Prior Jail Location Coming from Other County/location?  \
# 0                 No                 NaN                                 No
# ...

# %%
yak_detainers['County'] = yak_detainers['County'].str.replace(' County', '')

# %%
g = yak_detainers.groupby(['State', 'County'])['Count'].count()

# %%
df = g.reset_index()

# %%
df = df.rename({'State': 'State1', 'County': 'County1'}, axis=1)

# %%
df['State2'] = 'WA'
df['County2'] = 'Yakima'
df['FIPS2'] = 53077

# %%
df.head()
# Out:
#   State1     County1  Count State2 County2  FIPS2
# 0     ID         Ada    104     WA  Yakima  53077
# 1     ID     Bannock      5     WA  Yakima  53077
# 2     ID      Blaine      5     WA  Yakima  53077
# 3     ID  Bonneville      6     WA  Yakima  53077
# 4     ID    Boundary      1     WA  Yakima  53077

# %%
df = df.merge(fips, left_on=['State1', 'County1'], right_on=['State', 'County'])
df = df.drop(['County', 'State'], axis=1)
df = df.rename({'FIPS': 'FIPS1'}, axis=1)

# %%
df = df[df['State1'] != 'Unknown']
df = df[df['County1'] != 'Unknown']

# %%
df = df.sort_values(by='Count', ascending=True)

# %%
df = df.reset_index(drop=True)

# %%
df.tail(10)
# Out:
#    State1   County1  Count State2 County2  FIPS2  FIPS1
# 26     WA     Adams     36     WA  Yakima  53077  53001
# 27     WA    Pierce     38     WA  Yakima  53077  53053
# 28     WA    Chelan     41     WA  Yakima  53077  53007
# 29     WA  Okanogan     44     WA  Yakima  53077  53047
# 30     WA     Grant     71     WA  Yakima  53077  53025
# 31     WA    Benton     90     WA  Yakima  53077  53005
# 32     WA   Spokane     92     WA  Yakima  53077  53063
# 33     ID       Ada    104     WA  Yakima  53077  16001
# 34     WA  Franklin    146     WA  Yakima  53077  53021
# 35     WA    Yakima    157     WA  Yakima  53077  53077

# %%
# edges = df[['FIPS1', 'FIPS2']].values

# %%
G = nx.DiGraph()

# %%
county_dict = nw_counties.set_index('FIPS').to_dict('index')

# %%
pos = {county: (v['Longitude'], v['Latitude'])
       for county, v in
       county_dict.items()}

# %%
for row in df.values:
    G.add_edge(row[6], row[5], weight=row[2])

# %%
G.edges(data=True)
# Out:
# OutEdgeDataView([(30101, 53077, {'weight': 1}), (53077, 53077, {'weight': 157}), (53017, 53077, {'weight': 1}), (53073, 53077, {'weight': 1}), (16077, 53077, {'weight': 1}), (16073, 53077, {'weight': 1}), (16067, 53077, {'weight': 1}), (16053, 53077, {'weight': 1}), (16043, 53077, {'weight': 1}), (30053, 53077, {'weight': 1}), (53065, 53077, {'weight': 1}), (16021, 53077, {'weight': 1}), (30111, 53077, {'weight': 2}), (16055, 53077, {'weight': 3}), (16031, 53077, {'weight': 4}), (16027, 53077, {'weight': 4}), (53061, 53077, {'weight': 4}), (41059, 53077, {'weight': 4}), (16039, 53077, {'weight': 4}), (16013, 53077, {'weight': 5}), (16005, 53077, {'weight': 5}), (16019, 53077, {'weight': 6}), (53039, 53077, {'weight': 6}), (16051, 53077, {'weight': 7}), (16083, 53077, {'weight': 7}), (53071, 53077, {'weight': 8}), (53037, 53077, {'weight': 12}), (53001, 53077, {'weight': 36}), (53053, 53077, {'weight': 38}), (53007, 53077, {'weight': 41}), (53047, 53077, {'weight': 44}), (53025, 53077
# ...

# %%
weights = pd.Series([c for (u, v, c) in G.edges.data('weight', default=0)])

# %%
edge_weights = {edge: G.get_edge_data(edge[0], edge[1])['weight'] for edge in G.edges}
edges=sorted(G.edges(data=True), key=lambda t: t[2].get('weight', 1), reverse=True)

# %%
edge_colors = [weight / max(weights) for weight in weights]
edge_alphas = .5

# %%
hubs = pd.Series(G.nodes())[weights >= 50]
hubs = list(hubs)

# %%
labels = {}    
for node in G.nodes():
    if node in hubs:
        #set the node name as the key and the label as its value 
        labels[node] = county_dict[node]['County']
#set the argument 'with labels' to False so you have unlabeled graph
# nx.draw(G, with_labels=False)
#Now only add labels to the nodes you require (the hubs in my case)
# nx.draw_networkx_labels(G,pos,labels,font_size=16,font_color='r')

# %%
labels
# Out:
# {53077: 'Yakima',
#  53025: 'Grant',
#  53005: 'Benton',
#  53063: 'Spokane',
#  16001: 'Ada',
#  53021: 'Franklin'}

# %%
reader = shpreader.Reader('../input/countyl010g.shp')

counties = list(reader.geometries()) # This appears to just be county borders, no other attributes

COUNTIES = cfeature.ShapelyFeature(counties, ccrs.PlateCarree())

crs = ccrs.PlateCarree(central_longitude=0.0)

fig, ax = plt.subplots(
    1, 1, figsize=(10, 6),
    subplot_kw=dict(projection=crs))

# ax.add_feature(cfeature.LAND.with_scale('50m'))
ax.add_feature(cfeature.OCEAN.with_scale('50m'))
# ax.add_feature(cfeature.LAKES.with_scale('50m'))
ax.add_feature(COUNTIES, facecolor='none', edgecolor='gray', alpha=.5, zorder=0)
ax.add_feature(cfeature.STATES, facecolor='none', edgecolor='black', alpha=.5, zorder=0)
ax.coastlines('50m')

ax.set_extent([-125, -108, 41, 50]) # PNW 
# ax.set_extent([-126, -114, 41, 50]) # WA + ID
# ax.set_extent([-125, -116, 45, 49.2]) # WA

draw_edges = nx.draw_networkx_edges(G, pos, ax=ax,
                                    node_size=weights*2,
                                    arrowstyle='-',
                                    arrowsize=20,
                                    edge_color=edge_colors,
                                    edge_cmap=plt.cm.viridis,
                                    alpha=.1,
                                    width=2)
draw_nodes = nx.draw_networkx_nodes(G, pos, ax=ax,
                                    node_size=weights*2,
                                    node_color=edge_colors,
                                    alpha=1)

# draw_labels = nx.draw_networkx_labels(G, pos=pos, ax=ax, labels=labels, font_size=14)

vmin = df['Count'].min()
vmax = df['Count'].max()

pc = mpl.collections.PatchCollection(draw_edges, cmap=plt.cm.viridis,
                                     norm=plt.Normalize(vmin=vmin, vmax=vmax))
pc.set_array(edge_colors)
clb = plt.colorbar(pc, ax=ax, shrink=.7)
clb.set_label('Detainees', labelpad=-30, y=1.075, rotation=0)

plt.title(f"Prior location of ICE detainees transferred to\nYakima County Jail, Oct. 2016-Dec. 2017", size=18)

msg = '(Source: UW Center for Human Rights)'
txt = plt.figtext(0.65, .175, msg, wrap=True, horizontalalignment='center', fontsize=12)

fig.savefig(f'../output/yakima-jail-transfers.png', dpi=200, bbox_extra_artists=(pc,txt), bbox_inches='tight')


ax = plt.gca()
ax.set_axis_off()
plt.show()
